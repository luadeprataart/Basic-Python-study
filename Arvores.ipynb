# %% [markdown]
# <a href="https://colab.research.google.com/github/luadeprataart/Basic-Python-study/blob/main/Arvores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None
        
    def __str__(self):
        return str(self.data)
        
        
def inorder(Tree):
    if Tree:
        inorder(Tree.left)
        print(Tree.data)
        inorder(Tree.right)
    return
def preorder(Tree):
    if Tree:
        print(Tree.data)
        preorder(Tree.left)
        preorder(Tree.right)
        
        
def postorder(Tree):
    if Tree:
        postorder(Tree.left)
        postorder(Tree.right)
        print(Tree.data)
        
        
no = Node(5)
no2 = Node(10)
no3 = Node(8)
no4 = Node(2)
no.right = no2
no.left = no4
no2.left = no3
postorder(no)
# Out:
# 2
# 8
# 10
# 5

# %% [markdown]
# #**Árvore binária**
#
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None
        
    def __str__(self):
        return str(self.data)

class arvoreBinaria:
    def __init__(self, raiz = None):
      self.raiz = None

#Função para inserir um elemento na árvore------------------------------------------------------------------------ 
    def inserir(self, data, lado = -1):

      temporario = Node(data) # Cria um nó para data e salva em uma var temporaria
        
      if self.raiz is None:# Raiz vazia
        self.raiz = temporario
        return
      else: # Raiz já está sendo ocupada
        if lado is -1:# Primeira vez que adiciona em uma lista não vazia
          lado = self.raiz
        else:
          lado = lado  
        if lado.data > data:
          if lado.left is None:
           lado.left = temporario
          else:
            novoLado = lado.left
            self.inserir(data, novoLado)
        else: 
          if lado.right is None:
           lado.right = temporario
          else:
            novoLado = lado.right
            self.inserir(data, novoLado)

 #Função para inserir um elemento na árvore------------------------------------------------------------------------            
    def preOrdem(self , lado = -1):

      

     if self.raiz != None: #Não está vazia

      if lado is -1: 
       lado = self.raiz

      print(lado.data)

      if lado.left != None:
        lado = lado.left
        self.preOrdem(lado)
       
      if lado.right != None:  
        lado = lado.right
        self.preOrdem(lado)

     else: 
       print('Árvore vazia!')   
       return

# %%
arvore = arvoreBinaria()
arvore.preOrdem()

arvore.inserir(5)
arvore.preOrdem()
print ('\n')



arvore.inserir(1)
arvore.inserir(3)
arvore.inserir(2)
arvore.preOrdem()
print ('\n')
# Out:
# Árvore vazia!
# 5
#
#
# 5
# 1
# 3
# 2
# 3
# 2
